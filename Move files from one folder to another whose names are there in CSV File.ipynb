# %%
import pandas as pd
import os, shutil

# %%
df_files = pd.read_csv(r"D:\stand.csv")  #Location of CSV file

# %%
fileOrigin = r"D:\train/"  # Location of Origin from where photos are to be taken
fileDest= r"D:\Standing/"  # Location of Destination to where photos are to be moved

# %% [markdown]
# # Add the label of the columns as "ID" whose names are to be taken without "

# %%
for ff in df_files['ID'].tolist():
    print(f"Moving file {ff}")
    shutil.move(fileOrigin+ff, fileDest)
# Out:
# Moving file Image_37.jpg
# Moving file Image_38.jpg
# Moving file Image_50.jpg
# Moving file Image_75.jpg
# Moving file Image_85.jpg
# Moving file Image_107.jpg
# Moving file Image_114.jpg
# Moving file Image_170.jpg
# Moving file Image_183.jpg
# Moving file Image_186.jpg
# Moving file Image_214.jpg
# Moving file Image_218.jpg
# Moving file Image_224.jpg
# Moving file Image_228.jpg
# Moving file Image_233.jpg
# Moving file Image_238.jpg
# Moving file Image_245.jpg
# Moving file Image_260.jpg
# Moving file Image_266.jpg
# Moving file Image_296.jpg
# Moving file Image_306.jpg
# Moving file Image_307.jpg
# Moving file Image_312.jpg
# Moving file Image_316.jpg
# Moving file Image_328.jpg
# Moving file Image_335.jpg
# Moving file Image_345.jpg
# Moving file Image_347.jpg
# Moving file Image_348.jpg
# Moving file Image_400.jpg
# Moving file Image_414.jpg
# Moving file Image_428.jpg
# Moving file Image_450.jpg
# Moving file Image_489.jpg
# Moving file Image_517.jpg
# ...
